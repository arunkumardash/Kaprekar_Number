# %% [markdown]
# ### Following Code prints the *Kaprekar* Number for **4 digit numbers**
#
# ---

# %%
kaprekar_set=set()
def kaprekar_diff(n):
    nlist = list(str(n))
    if n < 1000:
        if len(nlist) == 1:
            nlist = nlist + list('000')
        elif len(nlist) == 2:
            nlist = nlist + list('00')
        elif len(nlist) == 3:
            nlist = nlist + list('0')
    maxn = int(''.join(sorted(nlist, reverse=True)))
    minn = int(''.join(sorted(nlist)))
    return maxn - minn

def find_kaprekar(n1):
    global kaprekar_set
    kpass = 1
    n2 = []
    while kpass <= 100:
        n1 = kaprekar_diff(n1)
        if n1 in n2:
            kaprekar_set.add(n1)
            break
        else:
            n2.append(n1)
            kpass += 1
        n1 = n2[-1]
    return kpass

print('**************************** for 4 digit numbers ****************************')
start,end = 1000,10000
p_max=set()
p_max.add(0)
for n in range(start,end):
    if n not in [1111,2222,3333,4444,5555,6666,7777,8888,9999]:
        kpass_out = find_kaprekar(n)
        if kpass_out > max(p_max):p_max.add(kpass_out)
print('Maximum number of passes:',max(p_max))
print('Kaprekar numbers: ')
l = list(kaprekar_set)
l.sort()
for i in l:
  print(i,end=' ')
# Out:
# **************************** for 4 digit numbers ****************************
# Maximum number of passes: 8
# Kaprekar numbers:
# 6174

# %% [markdown]
# ### Following Code prints the list of *Kaprekar* Numbers for **5 digit numbers**
#
# ---

# %%
kaprekar_set=set()
def kaprekar_diff(n):
    nlist = list(str(n))
    if n < 1000:
        if len(nlist) == 1:
            nlist = nlist + list('000')
        elif len(nlist) == 2:
            nlist = nlist + list('00')
        elif len(nlist) == 3:
            nlist = nlist + list('0')
    maxn = int(''.join(sorted(nlist, reverse=True)))
    minn = int(''.join(sorted(nlist)))
    return maxn - minn

def find_kaprekar(n1):
    global kaprekar_set
    kpass = 1
    n2 = []
    while kpass <= 100:
        n1 = kaprekar_diff(n1)
        if n1 in n2:
            kaprekar_set.add(n1)
            break
        else:
            n2.append(n1)
            kpass += 1
        n1 = n2[-1]
    return kpass
print('**************************** for 5 digit numbers ****************************')
start,end = 10000,100000
p_max=set()
p_max.add(0)
for n in range(start,end):
    if n not in [11111,22222,33333,44444,55555,66666,77777,88888,99999]:
        kpass_out = find_kaprekar(n)
        if kpass_out > max(p_max):p_max.add(kpass_out)
print('Max Passes:',max(p_max))
print('Kaprekar numbers: ')
l = list(kaprekar_set)
l.sort()
for i in l:
  print(i,end=' ')
# Out:
# **************************** for 5 digit numbers ****************************
# Max Passes: 10
# Kaprekar numbers:
# 0 53955 59994 61974 62964 63954 71973 74943 75933 82962 83952

# %% [markdown]
# ### Following Code prints the list of *Kaprekar* Numbers for **6 digit numbers**
#
# ---

# %%
kaprekar_set=set()
def kaprekar_diff(n):
    nlist = list(str(n))
    if n < 1000:
        if len(nlist) == 1:
            nlist = nlist + list('000')
        elif len(nlist) == 2:
            nlist = nlist + list('00')
        elif len(nlist) == 3:
            nlist = nlist + list('0')
    maxn = int(''.join(sorted(nlist, reverse=True)))
    minn = int(''.join(sorted(nlist)))
    return maxn - minn

def find_kaprekar(n1):
    global kaprekar_set
    kpass = 1
    n2 = []
    while kpass <= 100:
        n1 = kaprekar_diff(n1)
        if n1 in n2:
            kaprekar_set.add(n1)
            break
        else:
            n2.append(n1)
            kpass += 1
        n1 = n2[-1]
    return kpass
print('**************************** for 6 digit numbers ****************************')
start,end = 100000,1000000
p_max=set()
p_max.add(0)
for n in range(start,end):
    if n not in [111111,222222,333333,444444,555555,666666,777777,888888,999999]:
        kpass_out = find_kaprekar(n)
        if kpass_out > max(p_max):p_max.add(kpass_out)
print('Max Passes:',max(p_max))
print('Kaprekar numbers: ')
l = list(kaprekar_set)
l.sort()
for i in l:
  print(i,end=' ')
# Out:
# **************************** for 6 digit numbers ****************************
# Max Passes: 20
# Kaprekar numbers:
# 0 420876 549945 631764 642654 750843 840852 851742 860832 862632

# %% [markdown]
# # Result:
#
#
# 1.  There are more than one Kaprekar constant for number sets with digits greater than 4.
# 2.  Number of Kaprekar constants identified:
# > *   For 4-digit numbers: 1
# > *   For 5-digit numbers: 11
# > *   For 6-digit numbers: 10
# 3.  Zero is included as Kaprekar constant for 5 and 6 digit number sets.
